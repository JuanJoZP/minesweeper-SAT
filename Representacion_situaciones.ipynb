# %% [markdown]
# <table>
#     <tr>
#         <td><img src="./img/Macc.png" width="auto"/></td>
#         <td>
#             <table><tr>
#             <h1 style="color:blue;text-align:center">Lógica para Ciencias de la Computación</h1></td>
#             </tr></table>
#         <td>&nbsp;</td>
#         <td>
#             <table><tr>
#             <tp><p style="font-size:150%;text-align:center">Proyecto final</p></tp>
#             <tp><p style="font-size:150%;text-align:center">Buscaminas</p></tp>
#             </tr></table>
#         </td>
#     </tr>
# </table>
#
# ---

# %% [markdown]
# # Objetivo <a class="anchor" id="inicio"></a>
#
# En clase hemos visto cómo representar situaciones, sus restricciones, y el objetivo que se busca resolver, por medio de fórmulas lógicas. El objetivo de este taller es explorar cómo implementar en Python la representación de situaciones.

# %% [markdown]
# # Secciones
#
# 1. [Problema de ejemplo.](#prob)
# 2. [Descriptores.](#des)
# 3. [Implementación de restricciones.](#imp)

# %% [markdown]
# # Problema de ejemplo <a class="anchor" id="prob"></a>
#
# ([Volver al inicio](#inicio))
#
# Trabajaremos sobre el siguiente problema. Buscamos llenar todas las casillas en una tabla 2x2 con un número de 0 a 3, sin repetir. Por ejemplo:
#
# ![ejemplo](img/tabla.png)
#
# Tenemos tres restricciones que debemos implementar para resolver el problema:
#
# 1. Un número sólo está en una casilla.
# 2. No hay más de un número en una casilla.
# 3. Debe haber por lo menos un número en una casilla.

# %% [markdown]
# # Descriptores <a class="anchor" id="des"></a>
#
# ([Volver al inicio](#inicio))
#
# Debemos primero representar las letras proposicionales, las cuales cruzan la información de qué número está en qué casilla:
#
# $NenC_{x,y,n}$ es verdadera sii el número $n$ está en la casilla destapada $(x,y)$
#
# $MenC_{x,y}$ es verdadera sii hay una mina en la casilla tapada $(x,y)$
#
# Para hacer la implementación en python, sugerimos usar la clase `Descriptor`, que se encuentra en la librería `Logica`.  Básicamente, lo que hace la codificación es representar un átomo como un solo caracter (es decir, una cadena de longitud 1).
#
# Importamos la clase a partir de la librería:

# %%
from Logica import Descriptor

# %% [markdown]
# Ahora creamos un descriptor de tres argumentos, dos para la casilla $(x,y)$ y uno para los números:

# %%
BOARD_SIZE = 10
Nx = BOARD_SIZE
Ny = BOARD_SIZE
Nn = 7 # revisar si se puede bajar a 6
X = list(range(Nx))
Y = list(range(Ny))
NenC = Descriptor([Nx, Ny, Nn])

# %% [markdown]
# Métodos importantes del `Descriptor`:
#
# * P(`lista_valores`): Codifica el cruce de información correspondiente a los valores en `lista_valores` mediante un caracter.
# * inv(`caracter`): Decodifica `caracter` en una lista de valores. Esta lista depende del número de argumentos con que se haya inicializado el objeto descriptor.
#
# ### Codificando en un solo caracter
#
# Mediante el método P() podemos crear las codificaciones. A continuación presentaremos cada uno de los caracteres que codifican los cruces de información de que un número $n$ (con $n\in\{0, 1, 2, 3\}$) se encuentra en una casilla $(x,y)$ (donde $x,y\in\{0, 1\}$):

# %%
print("Cantidad de átomos NenC:", NenC.rango[1] - NenC.rango[0])
print("Caracteres correspondientes a los átomos NenC:\n")
for n in range(Nn):
    for x in range(Nx):
        for y in range(Ny):
            atomo = NenC.P([x,y,n])
            print(f"Que el número {n} está en la casilla ({x},{y}) es el átomo {atomo}")
    print("")
# Out:
# Cantidad de átomos NenC: 700
# Caracteres correspondientes a los átomos NenC:
#
# Que el número 0 está en la casilla (0,0) es el átomo Ā
# Que el número 0 está en la casilla (0,1) es el átomo Ċ
# Que el número 0 está en la casilla (0,2) es el átomo Ĕ
# Que el número 0 está en la casilla (0,3) es el átomo Ğ
# Que el número 0 está en la casilla (0,4) es el átomo Ĩ
# Que el número 0 está en la casilla (0,5) es el átomo Ĳ
# Que el número 0 está en la casilla (0,6) es el átomo ļ
# Que el número 0 está en la casilla (0,7) es el átomo ņ
# Que el número 0 está en la casilla (0,8) es el átomo Ő
# Que el número 0 está en la casilla (0,9) es el átomo Ś
# Que el número 0 está en la casilla (1,0) es el átomo ā
# Que el número 0 está en la casilla (1,1) es el átomo ċ
# Que el número 0 está en la casilla (1,2) es el átomo ĕ
# Que el número 0 está en la casilla (1,3) es el átomo ğ
# Que el número 0 está en la casilla (1,4) es el átomo ĩ
# Que el número 0 está en la casilla (1,5) es el átomo ĳ
# Que el número 0 está en la casilla (1,6) es el átomo Ľ
# Que el número 0 está en la casilla (1,7) es el átomo Ň
# Que el número 0 está en la casilla (1,8) es el átomo ő
# Que el número 0 está en la casilla (1,9) es el átomo ś
# Que el número 0 está en la casilla (2,0) es el átomo Ă
# Que el número 0 está en la casilla (2,1) es el átomo Č
# Que el número 0 está en la casilla (2,2) es el átomo Ė
# Que el número 0 está en la casilla (2,3) es el átomo Ġ
# Que el número 0 está en la casilla (2,4) es el átomo Ī
# Que el número 0 está en la casilla (2,5) es el átomo Ĵ
# Que el número 0 está en la casilla (2,6) es el átomo ľ
# Que el número 0 está en la casilla (2,7) es el átomo ň
# Que el número 0 está en la casilla (2,8) es el átomo Œ
# Que el número 0 está en la casilla (2,9) es el átomo Ŝ
# Que el número 0 está en la casilla (3,0) es el átomo ă
# Que el número 0 está en la casilla (3,1) es el átomo č
# Que el número 0 está en la casilla (3,2) es el átomo ė
# Que el número 0 está en la casilla (3,3) es el átomo ġ
# Que el número 0 está en la casilla (3,4) es el átomo ī
# Que el número 0 está en la casilla (3,5) es el átomo ĵ
# Que el número 0 está en la casilla (3,6) es el átomo Ŀ
# Que el número 0 está en la casilla (3,7) es el átomo ŉ
# Que el número 0 está en la casilla (3,8) es el átomo œ
# Que el número 0 está en la casilla (3,9) es el átomo ŝ
# Que el número 0 está en la casilla (4,0) es el átomo Ą
# Que el número 0 está en la casilla (4,1) es el átomo Ď
# Que el número 0 está en la casilla (4,2) es el átomo Ę
# Que el número 0 está en la casilla (4,3) es el átomo Ģ
# Que el número 0 está en la casilla (4,4) es el átomo Ĭ
# Que el número 0 está en la casilla (4,5) es el átomo Ķ
# Que el número 0 está en la casilla (4,6) es el átomo ŀ
# Que el número 0 está en la casilla (4,7) es el átomo Ŋ
# Que el número 0 está en la casilla (4,8) es el átomo Ŕ
# Que el número 0 está en la casilla (4,9) es el átomo Ş
# Que el número 0 está en la casilla (5,0) es el átomo ą
# Que el número 0 está en la casilla (5,1) es el átomo ď
# Que el número 0 está en la casilla (5,2) es el átomo ę
# Que el número 0 está en la casilla (5,3) es el átomo ģ
# Que el número 0 está en la casilla (5,4) es el átomo ĭ
# Que el número 0 está en la casilla (5,5) es el átomo ķ
# Que el número 0 está en la casilla (5,6) es el átomo Ł
# Que el número 0 está en la casilla (5,7) es el átomo ŋ
# Que el número 0 está en la casilla (5,8) es el átomo ŕ
# Que el número 0 está en la casilla (5,9) es el átomo ş
# Que el número 0 está en la casilla (6,0) es el átomo Ć
# Que el número 0 está en la casilla (6,1) es el átomo Đ
# Que el número 0 está en la casilla (6,2) es el átomo Ě
# Que el número 0 está en la casilla (6,3) es el átomo Ĥ
# Que el número 0 está en la casilla (6,4) es el átomo Į
# Que el número 0 está en la casilla (6,5) es el átomo ĸ
# Que el número 0 está en la casilla (6,6) es el átomo ł
# Que el número 0 está en la casilla (6,7) es el átomo Ō
# Que el número 0 está en la casilla (6,8) es el átomo Ŗ
# Que el número 0 está en la casilla (6,9) es el átomo Š
# Que el número 0 está en la casilla (7,0) es el átomo ć
# Que el número 0 está en la casilla (7,1) es el átomo đ
# Que el número 0 está en la casilla (7,2) es el átomo ě
# Que el número 0 está en la casilla (7,3) es el átomo ĥ
# Que el número 0 está en la casilla (7,4) es el átomo į
# Que el número 0 está en la casilla (7,5) es el átomo Ĺ
# Que el número 0 está en la casilla (7,6) es el átomo Ń
# Que el número 0 está en la casilla (7,7) es el átomo ō
# Que el número 0 está en la casilla (7,8) es el átomo ŗ
# Que el número 0 está en la casilla (7,9) es el átomo š
# Que el número 0 está en la casilla (8,0) es el átomo Ĉ
# Que el número 0 está en la casilla (8,1) es el átomo Ē
# Que el número 0 está en la casilla (8,2) es el átomo Ĝ
# Que el número 0 está en la casilla (8,3) es el átomo Ħ
# Que el número 0 está en la casilla (8,4) es el átomo İ
# Que el número 0 está en la casilla (8,5) es el átomo ĺ
# Que el número 0 está en la casilla (8,6) es el átomo ń
# Que el número 0 está en la casilla (8,7) es el átomo Ŏ
# Que el número 0 está en la casilla (8,8) es el átomo Ř
# Que el número 0 está en la casilla (8,9) es el átomo Ţ
# Que el número 0 está en la casilla (9,0) es el átomo ĉ
# Que el número 0 está en la casilla (9,1) es el átomo ē
# Que el número 0 está en la casilla (9,2) es el átomo ĝ
# Que el número 0 está en la casilla (9,3) es el átomo ħ
# Que el número 0 está en la casilla (9,4) es el átomo ı
# Que el número 0 está en la casilla (9,5) es el átomo Ļ
# Que el número 0 está en la casilla (9,6) es el átomo Ņ
# Que el número 0 está en la casilla (9,7) es el átomo ŏ
# Que el número 0 está en la casilla (9,8) es el átomo ř
# Que el número 0 está en la casilla (9,9) es el átomo ţ
#
# Que el número 1 está en la casilla (0,0) es el átomo Ť
# Que el número 1 está en la casilla (0,1) es el átomo Ů
# Que el número 1 está en la casilla (0,2) es el átomo Ÿ
# Que el número 1 está en la casilla (0,3) es el átomo Ƃ
# Que el número 1 está en la casilla (0,4) es el átomo ƌ
# Que el número 1 está en la casilla (0,5) es el átomo Ɩ
# Que el número 1 está en la casilla (0,6) es el átomo Ơ
# Que el número 1 está en la casilla (0,7) es el átomo ƪ
# Que el número 1 está en la casilla (0,8) es el átomo ƴ
# Que el número 1 está en la casilla (0,9) es el átomo ƾ
# Que el número 1 está en la casilla (1,0) es el átomo ť
# Que el número 1 está en la casilla (1,1) es el átomo ů
# Que el número 1 está en la casilla (1,2) es el átomo Ź
# Que el número 1 está en la casilla (1,3) es el átomo ƃ
# Que el número 1 está en la casilla (1,4) es el átomo ƍ
# Que el número 1 está en la casilla (1,5) es el átomo Ɨ
# Que el número 1 está en la casilla (1,6) es el átomo ơ
# Que el número 1 está en la casilla (1,7) es el átomo ƫ
# Que el número 1 está en la casilla (1,8) es el átomo Ƶ
# Que el número 1 está en la casilla (1,9) es el átomo ƿ
# Que el número 1 está en la casilla (2,0) es el átomo Ŧ
# Que el número 1 está en la casilla (2,1) es el átomo Ű
# Que el número 1 está en la casilla (2,2) es el átomo ź
# Que el número 1 está en la casilla (2,3) es el átomo Ƅ
# Que el número 1 está en la casilla (2,4) es el átomo Ǝ
# Que el número 1 está en la casilla (2,5) es el átomo Ƙ
# Que el número 1 está en la casilla (2,6) es el átomo Ƣ
# Que el número 1 está en la casilla (2,7) es el átomo Ƭ
# Que el número 1 está en la casilla (2,8) es el átomo ƶ
# Que el número 1 está en la casilla (2,9) es el átomo ǀ
# Que el número 1 está en la casilla (3,0) es el átomo ŧ
# Que el número 1 está en la casilla (3,1) es el átomo ű
# Que el número 1 está en la casilla (3,2) es el átomo Ż
# Que el número 1 está en la casilla (3,3) es el átomo ƅ
# Que el número 1 está en la casilla (3,4) es el átomo Ə
# Que el número 1 está en la casilla (3,5) es el átomo ƙ
# Que el número 1 está en la casilla (3,6) es el átomo ƣ
# Que el número 1 está en la casilla (3,7) es el átomo ƭ
# Que el número 1 está en la casilla (3,8) es el átomo Ʒ
# Que el número 1 está en la casilla (3,9) es el átomo ǁ
# Que el número 1 está en la casilla (4,0) es el átomo Ũ
# Que el número 1 está en la casilla (4,1) es el átomo Ų
# Que el número 1 está en la casilla (4,2) es el átomo ż
# Que el número 1 está en la casilla (4,3) es el átomo Ɔ
# Que el número 1 está en la casilla (4,4) es el átomo Ɛ
# Que el número 1 está en la casilla (4,5) es el átomo ƚ
# Que el número 1 está en la casilla (4,6) es el átomo Ƥ
# Que el número 1 está en la casilla (4,7) es el átomo Ʈ
# Que el número 1 está en la casilla (4,8) es el átomo Ƹ
# Que el número 1 está en la casilla (4,9) es el átomo ǂ
# Que el número 1 está en la casilla (5,0) es el átomo ũ
# Que el número 1 está en la casilla (5,1) es el átomo ų
# Que el número 1 está en la casilla (5,2) es el átomo Ž
# Que el número 1 está en la casilla (5,3) es el átomo Ƈ
# Que el número 1 está en la casilla (5,4) es el átomo Ƒ
# Que el número 1 está en la casilla (5,5) es el átomo ƛ
# Que el número 1 está en la casilla (5,6) es el átomo ƥ
# Que el número 1 está en la casilla (5,7) es el átomo Ư
# Que el número 1 está en la casilla (5,8) es el átomo ƹ
# Que el número 1 está en la casilla (5,9) es el átomo ǃ
# Que el número 1 está en la casilla (6,0) es el átomo Ū
# Que el número 1 está en la casilla (6,1) es el átomo Ŵ
# Que el número 1 está en la casilla (6,2) es el átomo ž
# Que el número 1 está en la casilla (6,3) es el átomo ƈ
# Que el número 1 está en la casilla (6,4) es el átomo ƒ
# Que el número 1 está en la casilla (6,5) es el átomo Ɯ
# Que el número 1 está en la casilla (6,6) es el átomo Ʀ
# Que el número 1 está en la casilla (6,7) es el átomo ư
# Que el número 1 está en la casilla (6,8) es el átomo ƺ
# Que el número 1 está en la casilla (6,9) es el átomo Ǆ
# Que el número 1 está en la casilla (7,0) es el átomo ū
# Que el número 1 está en la casilla (7,1) es el átomo ŵ
# Que el número 1 está en la casilla (7,2) es el átomo ſ
# Que el número 1 está en la casilla (7,3) es el átomo Ɖ
# Que el número 1 está en la casilla (7,4) es el átomo Ɠ
# Que el número 1 está en la casilla (7,5) es el átomo Ɲ
# Que el número 1 está en la casilla (7,6) es el átomo Ƨ
# Que el número 1 está en la casilla (7,7) es el átomo Ʊ
# Que el número 1 está en la casilla (7,8) es el átomo ƻ
# Que el número 1 está en la casilla (7,9) es el átomo ǅ
# Que el número 1 está en la casilla (8,0) es el átomo Ŭ
# Que el número 1 está en la casilla (8,1) es el átomo Ŷ
# Que el número 1 está en la casilla (8,2) es el átomo ƀ
# Que el número 1 está en la casilla (8,3) es el átomo Ɗ
# Que el número 1 está en la casilla (8,4) es el átomo Ɣ
# Que el número 1 está en la casilla (8,5) es el átomo ƞ
# Que el número 1 está en la casilla (8,6) es el átomo ƨ
# Que el número 1 está en la casilla (8,7) es el átomo Ʋ
# Que el número 1 está en la casilla (8,8) es el átomo Ƽ
# Que el número 1 está en la casilla (8,9) es el átomo ǆ
# Que el número 1 está en la casilla (9,0) es el átomo ŭ
# Que el número 1 está en la casilla (9,1) es el átomo ŷ
# Que el número 1 está en la casilla (9,2) es el átomo Ɓ
# Que el número 1 está en la casilla (9,3) es el átomo Ƌ
# Que el número 1 está en la casilla (9,4) es el átomo ƕ
# Que el número 1 está en la casilla (9,5) es el átomo Ɵ
# Que el número 1 está en la casilla (9,6) es el átomo Ʃ
# Que el número 1 está en la casilla (9,7) es el átomo Ƴ
# Que el número 1 está en la casilla (9,8) es el átomo ƽ
# Que el número 1 está en la casilla (9,9) es el átomo Ǉ
#
# Que el número 2 está en la casilla (0,0) es el átomo ǈ
# Que el número 2 está en la casilla (0,1) es el átomo ǒ
# Que el número 2 está en la casilla (0,2) es el átomo ǜ
# Que el número 2 está en la casilla (0,3) es el átomo Ǧ
# Que el número 2 está en la casilla (0,4) es el átomo ǰ
# Que el número 2 está en la casilla (0,5) es el átomo Ǻ
# Que el número 2 está en la casilla (0,6) es el átomo Ȅ
# Que el número 2 está en la casilla (0,7) es el átomo Ȏ
# Que el número 2 está en la casilla (0,8) es el átomo Ș
# Que el número 2 está en la casilla (0,9) es el átomo Ȣ
# Que el número 2 está en la casilla (1,0) es el átomo ǉ
# Que el número 2 está en la casilla (1,1) es el átomo Ǔ
# Que el número 2 está en la casilla (1,2) es el átomo ǝ
# Que el número 2 está en la casilla (1,3) es el átomo ǧ
# Que el número 2 está en la casilla (1,4) es el átomo Ǳ
# Que el número 2 está en la casilla (1,5) es el átomo ǻ
# Que el número 2 está en la casilla (1,6) es el átomo ȅ
# Que el número 2 está en la casilla (1,7) es el átomo ȏ
# Que el número 2 está en la casilla (1,8) es el átomo ș
# Que el número 2 está en la casilla (1,9) es el átomo ȣ
# Que el número 2 está en la casilla (2,0) es el átomo Ǌ
# Que el número 2 está en la casilla (2,1) es el átomo ǔ
# Que el número 2 está en la casilla (2,2) es el átomo Ǟ
# Que el número 2 está en la casilla (2,3) es el átomo Ǩ
# Que el número 2 está en la casilla (2,4) es el átomo ǲ
# Que el número 2 está en la casilla (2,5) es el átomo Ǽ
# Que el número 2 está en la casilla (2,6) es el átomo Ȇ
# Que el número 2 está en la casilla (2,7) es el átomo Ȑ
# Que el número 2 está en la casilla (2,8) es el átomo Ț
# Que el número 2 está en la casilla (2,9) es el átomo Ȥ
# Que el número 2 está en la casilla (3,0) es el átomo ǋ
# Que el número 2 está en la casilla (3,1) es el átomo Ǖ
# Que el número 2 está en la casilla (3,2) es el átomo ǟ
# Que el número 2 está en la casilla (3,3) es el átomo ǩ
# Que el número 2 está en la casilla (3,4) es el átomo ǳ
# Que el número 2 está en la casilla (3,5) es el átomo ǽ
# Que el número 2 está en la casilla (3,6) es el átomo ȇ
# Que el número 2 está en la casilla (3,7) es el átomo ȑ
# Que el número 2 está en la casilla (3,8) es el átomo ț
# Que el número 2 está en la casilla (3,9) es el átomo ȥ
# Que el número 2 está en la casilla (4,0) es el átomo ǌ
# Que el número 2 está en la casilla (4,1) es el átomo ǖ
# Que el número 2 está en la casilla (4,2) es el átomo Ǡ
# Que el número 2 está en la casilla (4,3) es el átomo Ǫ
# Que el número 2 está en la casilla (4,4) es el átomo Ǵ
# Que el número 2 está en la casilla (4,5) es el átomo Ǿ
# Que el número 2 está en la casilla (4,6) es el átomo Ȉ
# Que el número 2 está en la casilla (4,7) es el átomo Ȓ
# Que el número 2 está en la casilla (4,8) es el átomo Ȝ
# Que el número 2 está en la casilla (4,9) es el átomo Ȧ
# Que el número 2 está en la casilla (5,0) es el átomo Ǎ
# Que el número 2 está en la casilla (5,1) es el átomo Ǘ
# Que el número 2 está en la casilla (5,2) es el átomo ǡ
# Que el número 2 está en la casilla (5,3) es el átomo ǫ
# Que el número 2 está en la casilla (5,4) es el átomo ǵ
# Que el número 2 está en la casilla (5,5) es el átomo ǿ
# Que el número 2 está en la casilla (5,6) es el átomo ȉ
# Que el número 2 está en la casilla (5,7) es el átomo ȓ
# Que el número 2 está en la casilla (5,8) es el átomo ȝ
# Que el número 2 está en la casilla (5,9) es el átomo ȧ
# Que el número 2 está en la casilla (6,0) es el átomo ǎ
# Que el número 2 está en la casilla (6,1) es el átomo ǘ
# Que el número 2 está en la casilla (6,2) es el átomo Ǣ
# Que el número 2 está en la casilla (6,3) es el átomo Ǭ
# Que el número 2 está en la casilla (6,4) es el átomo Ƕ
# Que el número 2 está en la casilla (6,5) es el átomo Ȁ
# Que el número 2 está en la casilla (6,6) es el átomo Ȋ
# Que el número 2 está en la casilla (6,7) es el átomo Ȕ
# Que el número 2 está en la casilla (6,8) es el átomo Ȟ
# Que el número 2 está en la casilla (6,9) es el átomo Ȩ
# Que el número 2 está en la casilla (7,0) es el átomo Ǐ
# Que el número 2 está en la casilla (7,1) es el átomo Ǚ
# Que el número 2 está en la casilla (7,2) es el átomo ǣ
# Que el número 2 está en la casilla (7,3) es el átomo ǭ
# Que el número 2 está en la casilla (7,4) es el átomo Ƿ
# Que el número 2 está en la casilla (7,5) es el átomo ȁ
# Que el número 2 está en la casilla (7,6) es el átomo ȋ
# Que el número 2 está en la casilla (7,7) es el átomo ȕ
# Que el número 2 está en la casilla (7,8) es el átomo ȟ
# Que el número 2 está en la casilla (7,9) es el átomo ȩ
# Que el número 2 está en la casilla (8,0) es el átomo ǐ
# Que el número 2 está en la casilla (8,1) es el átomo ǚ
# Que el número 2 está en la casilla (8,2) es el átomo Ǥ
# Que el número 2 está en la casilla (8,3) es el átomo Ǯ
# Que el número 2 está en la casilla (8,4) es el átomo Ǹ
# Que el número 2 está en la casilla (8,5) es el átomo Ȃ
# Que el número 2 está en la casilla (8,6) es el átomo Ȍ
# Que el número 2 está en la casilla (8,7) es el átomo Ȗ
# Que el número 2 está en la casilla (8,8) es el átomo Ƞ
# Que el número 2 está en la casilla (8,9) es el átomo Ȫ
# Que el número 2 está en la casilla (9,0) es el átomo Ǒ
# Que el número 2 está en la casilla (9,1) es el átomo Ǜ
# Que el número 2 está en la casilla (9,2) es el átomo ǥ
# Que el número 2 está en la casilla (9,3) es el átomo ǯ
# Que el número 2 está en la casilla (9,4) es el átomo ǹ
# Que el número 2 está en la casilla (9,5) es el átomo ȃ
# Que el número 2 está en la casilla (9,6) es el átomo ȍ
# Que el número 2 está en la casilla (9,7) es el átomo ȗ
# Que el número 2 está en la casilla (9,8) es el átomo ȡ
# Que el número 2 está en la casilla (9,9) es el átomo ȫ
#
# Que el número 3 está en la casilla (0,0) es el átomo Ȭ
# Que el número 3 está en la casilla (0,1) es el átomo ȶ
# Que el número 3 está en la casilla (0,2) es el átomo ɀ
# Que el número 3 está en la casilla (0,3) es el átomo Ɋ
# Que el número 3 está en la casilla (0,4) es el átomo ɔ
# Que el número 3 está en la casilla (0,5) es el átomo ɞ
# Que el número 3 está en la casilla (0,6) es el átomo ɨ
# Que el número 3 está en la casilla (0,7) es el átomo ɲ
# Que el número 3 está en la casilla (0,8) es el átomo ɼ
# Que el número 3 está en la casilla (0,9) es el átomo ʆ
# Que el número 3 está en la casilla (1,0) es el átomo ȭ
# Que el número 3 está en la casilla (1,1) es el átomo ȷ
# Que el número 3 está en la casilla (1,2) es el átomo Ɂ
# Que el número 3 está en la casilla (1,3) es el átomo ɋ
# Que el número 3 está en la casilla (1,4) es el átomo ɕ
# Que el número 3 está en la casilla (1,5) es el átomo ɟ
# Que el número 3 está en la casilla (1,6) es el átomo ɩ
# Que el número 3 está en la casilla (1,7) es el átomo ɳ
# Que el número 3 está en la casilla (1,8) es el átomo ɽ
# Que el número 3 está en la casilla (1,9) es el átomo ʇ
# Que el número 3 está en la casilla (2,0) es el átomo Ȯ
# Que el número 3 está en la casilla (2,1) es el átomo ȸ
# Que el número 3 está en la casilla (2,2) es el átomo ɂ
# Que el número 3 está en la casilla (2,3) es el átomo Ɍ
# Que el número 3 está en la casilla (2,4) es el átomo ɖ
# Que el número 3 está en la casilla (2,5) es el átomo ɠ
# Que el número 3 está en la casilla (2,6) es el átomo ɪ
# Que el número 3 está en la casilla (2,7) es el átomo ɴ
# Que el número 3 está en la casilla (2,8) es el átomo ɾ
# Que el número 3 está en la casilla (2,9) es el átomo ʈ
# Que el número 3 está en la casilla (3,0) es el átomo ȯ
# Que el número 3 está en la casilla (3,1) es el átomo ȹ
# Que el número 3 está en la casilla (3,2) es el átomo Ƀ
# Que el número 3 está en la casilla (3,3) es el átomo ɍ
# Que el número 3 está en la casilla (3,4) es el átomo ɗ
# Que el número 3 está en la casilla (3,5) es el átomo ɡ
# Que el número 3 está en la casilla (3,6) es el átomo ɫ
# Que el número 3 está en la casilla (3,7) es el átomo ɵ
# Que el número 3 está en la casilla (3,8) es el átomo ɿ
# Que el número 3 está en la casilla (3,9) es el átomo ʉ
# Que el número 3 está en la casilla (4,0) es el átomo Ȱ
# Que el número 3 está en la casilla (4,1) es el átomo Ⱥ
# Que el número 3 está en la casilla (4,2) es el átomo Ʉ
# Que el número 3 está en la casilla (4,3) es el átomo Ɏ
# Que el número 3 está en la casilla (4,4) es el átomo ɘ
# Que el número 3 está en la casilla (4,5) es el átomo ɢ
# Que el número 3 está en la casilla (4,6) es el átomo ɬ
# Que el número 3 está en la casilla (4,7) es el átomo ɶ
# Que el número 3 está en la casilla (4,8) es el átomo ʀ
# Que el número 3 está en la casilla (4,9) es el átomo ʊ
# Que el número 3 está en la casilla (5,0) es el átomo ȱ
# Que el número 3 está en la casilla (5,1) es el átomo Ȼ
# Que el número 3 está en la casilla (5,2) es el átomo Ʌ
# Que el número 3 está en la casilla (5,3) es el átomo ɏ
# Que el número 3 está en la casilla (5,4) es el átomo ə
# Que el número 3 está en la casilla (5,5) es el átomo ɣ
# Que el número 3 está en la casilla (5,6) es el átomo ɭ
# Que el número 3 está en la casilla (5,7) es el átomo ɷ
# Que el número 3 está en la casilla (5,8) es el átomo ʁ
# Que el número 3 está en la casilla (5,9) es el átomo ʋ
# Que el número 3 está en la casilla (6,0) es el átomo Ȳ
# Que el número 3 está en la casilla (6,1) es el átomo ȼ
# Que el número 3 está en la casilla (6,2) es el átomo Ɇ
# Que el número 3 está en la casilla (6,3) es el átomo ɐ
# Que el número 3 está en la casilla (6,4) es el átomo ɚ
# Que el número 3 está en la casilla (6,5) es el átomo ɤ
# Que el número 3 está en la casilla (6,6) es el átomo ɮ
# Que el número 3 está en la casilla (6,7) es el átomo ɸ
# Que el número 3 está en la casilla (6,8) es el átomo ʂ
# Que el número 3 está en la casilla (6,9) es el átomo ʌ
# Que el número 3 está en la casilla (7,0) es el átomo ȳ
# Que el número 3 está en la casilla (7,1) es el átomo Ƚ
# Que el número 3 está en la casilla (7,2) es el átomo ɇ
# Que el número 3 está en la casilla (7,3) es el átomo ɑ
# Que el número 3 está en la casilla (7,4) es el átomo ɛ
# Que el número 3 está en la casilla (7,5) es el átomo ɥ
# Que el número 3 está en la casilla (7,6) es el átomo ɯ
# Que el número 3 está en la casilla (7,7) es el átomo ɹ
# Que el número 3 está en la casilla (7,8) es el átomo ʃ
# Que el número 3 está en la casilla (7,9) es el átomo ʍ
# Que el número 3 está en la casilla (8,0) es el átomo ȴ
# Que el número 3 está en la casilla (8,1) es el átomo Ⱦ
# Que el número 3 está en la casilla (8,2) es el átomo Ɉ
# Que el número 3 está en la casilla (8,3) es el átomo ɒ
# Que el número 3 está en la casilla (8,4) es el átomo ɜ
# Que el número 3 está en la casilla (8,5) es el átomo ɦ
# Que el número 3 está en la casilla (8,6) es el átomo ɰ
# Que el número 3 está en la casilla (8,7) es el átomo ɺ
# Que el número 3 está en la casilla (8,8) es el átomo ʄ
# Que el número 3 está en la casilla (8,9) es el átomo ʎ
# Que el número 3 está en la casilla (9,0) es el átomo ȵ
# Que el número 3 está en la casilla (9,1) es el átomo ȿ
# Que el número 3 está en la casilla (9,2) es el átomo ɉ
# Que el número 3 está en la casilla (9,3) es el átomo ɓ
# Que el número 3 está en la casilla (9,4) es el átomo ɝ
# Que el número 3 está en la casilla (9,5) es el átomo ɧ
# Que el número 3 está en la casilla (9,6) es el átomo ɱ
# Que el número 3 está en la casilla (9,7) es el átomo ɻ
# Que el número 3 está en la casilla (9,8) es el átomo ʅ
# Que el número 3 está en la casilla (9,9) es el átomo ʏ
#
# Que el número 4 está en la casilla (0,0) es el átomo ʐ
# Que el número 4 está en la casilla (0,1) es el átomo ʚ
# Que el número 4 está en la casilla (0,2) es el átomo ʤ
# Que el número 4 está en la casilla (0,3) es el átomo ʮ
# Que el número 4 está en la casilla (0,4) es el átomo ʸ
# Que el número 4 está en la casilla (0,5) es el átomo ˂
# Que el número 4 está en la casilla (0,6) es el átomo ˌ
# Que el número 4 está en la casilla (0,7) es el átomo ˖
# Que el número 4 está en la casilla (0,8) es el átomo ˠ
# Que el número 4 está en la casilla (0,9) es el átomo ˪
# Que el número 4 está en la casilla (1,0) es el átomo ʑ
# Que el número 4 está en la casilla (1,1) es el átomo ʛ
# Que el número 4 está en la casilla (1,2) es el átomo ʥ
# Que el número 4 está en la casilla (1,3) es el átomo ʯ
# Que el número 4 está en la casilla (1,4) es el átomo ʹ
# Que el número 4 está en la casilla (1,5) es el átomo ˃
# Que el número 4 está en la casilla (1,6) es el átomo ˍ
# Que el número 4 está en la casilla (1,7) es el átomo ˗
# Que el número 4 está en la casilla (1,8) es el átomo ˡ
# Que el número 4 está en la casilla (1,9) es el átomo ˫
# Que el número 4 está en la casilla (2,0) es el átomo ʒ
# Que el número 4 está en la casilla (2,1) es el átomo ʜ
# Que el número 4 está en la casilla (2,2) es el átomo ʦ
# Que el número 4 está en la casilla (2,3) es el átomo ʰ
# Que el número 4 está en la casilla (2,4) es el átomo ʺ
# Que el número 4 está en la casilla (2,5) es el átomo ˄
# Que el número 4 está en la casilla (2,6) es el átomo ˎ
# Que el número 4 está en la casilla (2,7) es el átomo ˘
# Que el número 4 está en la casilla (2,8) es el átomo ˢ
# Que el número 4 está en la casilla (2,9) es el átomo ˬ
# Que el número 4 está en la casilla (3,0) es el átomo ʓ
# Que el número 4 está en la casilla (3,1) es el átomo ʝ
# Que el número 4 está en la casilla (3,2) es el átomo ʧ
# Que el número 4 está en la casilla (3,3) es el átomo ʱ
# Que el número 4 está en la casilla (3,4) es el átomo ʻ
# Que el número 4 está en la casilla (3,5) es el átomo ˅
# Que el número 4 está en la casilla (3,6) es el átomo ˏ
# Que el número 4 está en la casilla (3,7) es el átomo ˙
# Que el número 4 está en la casilla (3,8) es el átomo ˣ
# Que el número 4 está en la casilla (3,9) es el átomo ˭
# Que el número 4 está en la casilla (4,0) es el átomo ʔ
# Que el número 4 está en la casilla (4,1) es el átomo ʞ
# Que el número 4 está en la casilla (4,2) es el átomo ʨ
# Que el número 4 está en la casilla (4,3) es el átomo ʲ
# Que el número 4 está en la casilla (4,4) es el átomo ʼ
# Que el número 4 está en la casilla (4,5) es el átomo ˆ
# Que el número 4 está en la casilla (4,6) es el átomo ː
# Que el número 4 está en la casilla (4,7) es el átomo ˚
# Que el número 4 está en la casilla (4,8) es el átomo ˤ
# Que el número 4 está en la casilla (4,9) es el átomo ˮ
# Que el número 4 está en la casilla (5,0) es el átomo ʕ
# Que el número 4 está en la casilla (5,1) es el átomo ʟ
# Que el número 4 está en la casilla (5,2) es el átomo ʩ
# Que el número 4 está en la casilla (5,3) es el átomo ʳ
# Que el número 4 está en la casilla (5,4) es el átomo ʽ
# Que el número 4 está en la casilla (5,5) es el átomo ˇ
# Que el número 4 está en la casilla (5,6) es el átomo ˑ
# Que el número 4 está en la casilla (5,7) es el átomo ˛
# Que el número 4 está en la casilla (5,8) es el átomo ˥
# Que el número 4 está en la casilla (5,9) es el átomo ˯
# Que el número 4 está en la casilla (6,0) es el átomo ʖ
# Que el número 4 está en la casilla (6,1) es el átomo ʠ
# Que el número 4 está en la casilla (6,2) es el átomo ʪ
# Que el número 4 está en la casilla (6,3) es el átomo ʴ
# Que el número 4 está en la casilla (6,4) es el átomo ʾ
# Que el número 4 está en la casilla (6,5) es el átomo ˈ
# Que el número 4 está en la casilla (6,6) es el átomo ˒
# Que el número 4 está en la casilla (6,7) es el átomo ˜
# Que el número 4 está en la casilla (6,8) es el átomo ˦
# Que el número 4 está en la casilla (6,9) es el átomo ˰
# Que el número 4 está en la casilla (7,0) es el átomo ʗ
# Que el número 4 está en la casilla (7,1) es el átomo ʡ
# Que el número 4 está en la casilla (7,2) es el átomo ʫ
# Que el número 4 está en la casilla (7,3) es el átomo ʵ
# Que el número 4 está en la casilla (7,4) es el átomo ʿ
# Que el número 4 está en la casilla (7,5) es el átomo ˉ
# Que el número 4 está en la casilla (7,6) es el átomo ˓
# Que el número 4 está en la casilla (7,7) es el átomo ˝
# Que el número 4 está en la casilla (7,8) es el átomo ˧
# Que el número 4 está en la casilla (7,9) es el átomo ˱
# Que el número 4 está en la casilla (8,0) es el átomo ʘ
# Que el número 4 está en la casilla (8,1) es el átomo ʢ
# Que el número 4 está en la casilla (8,2) es el átomo ʬ
# Que el número 4 está en la casilla (8,3) es el átomo ʶ
# Que el número 4 está en la casilla (8,4) es el átomo ˀ
# Que el número 4 está en la casilla (8,5) es el átomo ˊ
# Que el número 4 está en la casilla (8,6) es el átomo ˔
# Que el número 4 está en la casilla (8,7) es el átomo ˞
# Que el número 4 está en la casilla (8,8) es el átomo ˨
# Que el número 4 está en la casilla (8,9) es el átomo ˲
# Que el número 4 está en la casilla (9,0) es el átomo ʙ
# Que el número 4 está en la casilla (9,1) es el átomo ʣ
# Que el número 4 está en la casilla (9,2) es el átomo ʭ
# Que el número 4 está en la casilla (9,3) es el átomo ʷ
# Que el número 4 está en la casilla (9,4) es el átomo ˁ
# Que el número 4 está en la casilla (9,5) es el átomo ˋ
# Que el número 4 está en la casilla (9,6) es el átomo ˕
# Que el número 4 está en la casilla (9,7) es el átomo ˟
# Que el número 4 está en la casilla (9,8) es el átomo ˩
# Que el número 4 está en la casilla (9,9) es el átomo ˳
#
# Que el número 5 está en la casilla (0,0) es el átomo ˴
# Que el número 5 está en la casilla (0,1) es el átomo ˾
# Que el número 5 está en la casilla (0,2) es el átomo ̈
# Que el número 5 está en la casilla (0,3) es el átomo ̒
# Que el número 5 está en la casilla (0,4) es el átomo ̜
# Que el número 5 está en la casilla (0,5) es el átomo ̦
# Que el número 5 está en la casilla (0,6) es el átomo ̰
# Que el número 5 está en la casilla (0,7) es el átomo ̺
# Que el número 5 está en la casilla (0,8) es el átomo ̈́
# Que el número 5 está en la casilla (0,9) es el átomo ͎
# Que el número 5 está en la casilla (1,0) es el átomo ˵
# Que el número 5 está en la casilla (1,1) es el átomo ˿
# Que el número 5 está en la casilla (1,2) es el átomo ̉
# Que el número 5 está en la casilla (1,3) es el átomo ̓
# Que el número 5 está en la casilla (1,4) es el átomo ̝
# Que el número 5 está en la casilla (1,5) es el átomo ̧
# Que el número 5 está en la casilla (1,6) es el átomo ̱
# Que el número 5 está en la casilla (1,7) es el átomo ̻
# Que el número 5 está en la casilla (1,8) es el átomo ͅ
# Que el número 5 está en la casilla (1,9) es el átomo ͏
# Que el número 5 está en la casilla (2,0) es el átomo ˶
# Que el número 5 está en la casilla (2,1) es el átomo ̀
# Que el número 5 está en la casilla (2,2) es el átomo ̊
# Que el número 5 está en la casilla (2,3) es el átomo ̔
# Que el número 5 está en la casilla (2,4) es el átomo ̞
# Que el número 5 está en la casilla (2,5) es el átomo ̨
# Que el número 5 está en la casilla (2,6) es el átomo ̲
# Que el número 5 está en la casilla (2,7) es el átomo ̼
# Que el número 5 está en la casilla (2,8) es el átomo ͆
# Que el número 5 está en la casilla (2,9) es el átomo ͐
# Que el número 5 está en la casilla (3,0) es el átomo ˷
# Que el número 5 está en la casilla (3,1) es el átomo ́
# Que el número 5 está en la casilla (3,2) es el átomo ̋
# Que el número 5 está en la casilla (3,3) es el átomo ̕
# Que el número 5 está en la casilla (3,4) es el átomo ̟
# Que el número 5 está en la casilla (3,5) es el átomo ̩
# Que el número 5 está en la casilla (3,6) es el átomo ̳
# Que el número 5 está en la casilla (3,7) es el átomo ̽
# Que el número 5 está en la casilla (3,8) es el átomo ͇
# Que el número 5 está en la casilla (3,9) es el átomo ͑
# Que el número 5 está en la casilla (4,0) es el átomo ˸
# Que el número 5 está en la casilla (4,1) es el átomo ̂
# Que el número 5 está en la casilla (4,2) es el átomo ̌
# Que el número 5 está en la casilla (4,3) es el átomo ̖
# Que el número 5 está en la casilla (4,4) es el átomo ̠
# Que el número 5 está en la casilla (4,5) es el átomo ̪
# Que el número 5 está en la casilla (4,6) es el átomo ̴
# Que el número 5 está en la casilla (4,7) es el átomo ̾
# Que el número 5 está en la casilla (4,8) es el átomo ͈
# Que el número 5 está en la casilla (4,9) es el átomo ͒
# Que el número 5 está en la casilla (5,0) es el átomo ˹
# Que el número 5 está en la casilla (5,1) es el átomo ̃
# Que el número 5 está en la casilla (5,2) es el átomo ̍
# Que el número 5 está en la casilla (5,3) es el átomo ̗
# Que el número 5 está en la casilla (5,4) es el átomo ̡
# Que el número 5 está en la casilla (5,5) es el átomo ̫
# Que el número 5 está en la casilla (5,6) es el átomo ̵
# Que el número 5 está en la casilla (5,7) es el átomo ̿
# Que el número 5 está en la casilla (5,8) es el átomo ͉
# Que el número 5 está en la casilla (5,9) es el átomo ͓
# Que el número 5 está en la casilla (6,0) es el átomo ˺
# Que el número 5 está en la casilla (6,1) es el átomo ̄
# Que el número 5 está en la casilla (6,2) es el átomo ̎
# Que el número 5 está en la casilla (6,3) es el átomo ̘
# Que el número 5 está en la casilla (6,4) es el átomo ̢
# Que el número 5 está en la casilla (6,5) es el átomo ̬
# Que el número 5 está en la casilla (6,6) es el átomo ̶
# Que el número 5 está en la casilla (6,7) es el átomo ̀
# Que el número 5 está en la casilla (6,8) es el átomo ͊
# Que el número 5 está en la casilla (6,9) es el átomo ͔
# Que el número 5 está en la casilla (7,0) es el átomo ˻
# Que el número 5 está en la casilla (7,1) es el átomo ̅
# Que el número 5 está en la casilla (7,2) es el átomo ̏
# Que el número 5 está en la casilla (7,3) es el átomo ̙
# Que el número 5 está en la casilla (7,4) es el átomo ̣
# Que el número 5 está en la casilla (7,5) es el átomo ̭
# Que el número 5 está en la casilla (7,6) es el átomo ̷
# Que el número 5 está en la casilla (7,7) es el átomo ́
# Que el número 5 está en la casilla (7,8) es el átomo ͋
# Que el número 5 está en la casilla (7,9) es el átomo ͕
# Que el número 5 está en la casilla (8,0) es el átomo ˼
# Que el número 5 está en la casilla (8,1) es el átomo ̆
# Que el número 5 está en la casilla (8,2) es el átomo ̐
# Que el número 5 está en la casilla (8,3) es el átomo ̚
# Que el número 5 está en la casilla (8,4) es el átomo ̤
# Que el número 5 está en la casilla (8,5) es el átomo ̮
# Que el número 5 está en la casilla (8,6) es el átomo ̸
# Que el número 5 está en la casilla (8,7) es el átomo ͂
# Que el número 5 está en la casilla (8,8) es el átomo ͌
# Que el número 5 está en la casilla (8,9) es el átomo ͖
# Que el número 5 está en la casilla (9,0) es el átomo ˽
# Que el número 5 está en la casilla (9,1) es el átomo ̇
# Que el número 5 está en la casilla (9,2) es el átomo ̑
# Que el número 5 está en la casilla (9,3) es el átomo ̛
# Que el número 5 está en la casilla (9,4) es el átomo ̥
# Que el número 5 está en la casilla (9,5) es el átomo ̯
# Que el número 5 está en la casilla (9,6) es el átomo ̹
# Que el número 5 está en la casilla (9,7) es el átomo ̓
# Que el número 5 está en la casilla (9,8) es el átomo ͍
# Que el número 5 está en la casilla (9,9) es el átomo ͗
#
# Que el número 6 está en la casilla (0,0) es el átomo ͘
# Que el número 6 está en la casilla (0,1) es el átomo ͢
# Que el número 6 está en la casilla (0,2) es el átomo ͬ
# Que el número 6 está en la casilla (0,3) es el átomo Ͷ
# Que el número 6 está en la casilla (0,4) es el átomo ΀
# Que el número 6 está en la casilla (0,5) es el átomo Ί
# Que el número 6 está en la casilla (0,6) es el átomo Δ
# Que el número 6 está en la casilla (0,7) es el átomo Ξ
# Que el número 6 está en la casilla (0,8) es el átomo Ψ
# Que el número 6 está en la casilla (0,9) es el átomo β
# Que el número 6 está en la casilla (1,0) es el átomo ͙
# Que el número 6 está en la casilla (1,1) es el átomo ͣ
# Que el número 6 está en la casilla (1,2) es el átomo ͭ
# Que el número 6 está en la casilla (1,3) es el átomo ͷ
# Que el número 6 está en la casilla (1,4) es el átomo ΁
# Que el número 6 está en la casilla (1,5) es el átomo ΋
# Que el número 6 está en la casilla (1,6) es el átomo Ε
# Que el número 6 está en la casilla (1,7) es el átomo Ο
# Que el número 6 está en la casilla (1,8) es el átomo Ω
# Que el número 6 está en la casilla (1,9) es el átomo γ
# Que el número 6 está en la casilla (2,0) es el átomo ͚
# Que el número 6 está en la casilla (2,1) es el átomo ͤ
# Que el número 6 está en la casilla (2,2) es el átomo ͮ
# Que el número 6 está en la casilla (2,3) es el átomo ͸
# Que el número 6 está en la casilla (2,4) es el átomo ΂
# Que el número 6 está en la casilla (2,5) es el átomo Ό
# Que el número 6 está en la casilla (2,6) es el átomo Ζ
# Que el número 6 está en la casilla (2,7) es el átomo Π
# Que el número 6 está en la casilla (2,8) es el átomo Ϊ
# Que el número 6 está en la casilla (2,9) es el átomo δ
# Que el número 6 está en la casilla (3,0) es el átomo ͛
# Que el número 6 está en la casilla (3,1) es el átomo ͥ
# Que el número 6 está en la casilla (3,2) es el átomo ͯ
# Que el número 6 está en la casilla (3,3) es el átomo ͹
# Que el número 6 está en la casilla (3,4) es el átomo ΃
# Que el número 6 está en la casilla (3,5) es el átomo ΍
# Que el número 6 está en la casilla (3,6) es el átomo Η
# Que el número 6 está en la casilla (3,7) es el átomo Ρ
# Que el número 6 está en la casilla (3,8) es el átomo Ϋ
# Que el número 6 está en la casilla (3,9) es el átomo ε
# Que el número 6 está en la casilla (4,0) es el átomo ͜
# Que el número 6 está en la casilla (4,1) es el átomo ͦ
# Que el número 6 está en la casilla (4,2) es el átomo Ͱ
# Que el número 6 está en la casilla (4,3) es el átomo ͺ
# Que el número 6 está en la casilla (4,4) es el átomo ΄
# Que el número 6 está en la casilla (4,5) es el átomo Ύ
# Que el número 6 está en la casilla (4,6) es el átomo Θ
# Que el número 6 está en la casilla (4,7) es el átomo ΢
# Que el número 6 está en la casilla (4,8) es el átomo ά
# Que el número 6 está en la casilla (4,9) es el átomo ζ
# Que el número 6 está en la casilla (5,0) es el átomo ͝
# Que el número 6 está en la casilla (5,1) es el átomo ͧ
# Que el número 6 está en la casilla (5,2) es el átomo ͱ
# Que el número 6 está en la casilla (5,3) es el átomo ͻ
# Que el número 6 está en la casilla (5,4) es el átomo ΅
# Que el número 6 está en la casilla (5,5) es el átomo Ώ
# Que el número 6 está en la casilla (5,6) es el átomo Ι
# Que el número 6 está en la casilla (5,7) es el átomo Σ
# Que el número 6 está en la casilla (5,8) es el átomo έ
# Que el número 6 está en la casilla (5,9) es el átomo η
# Que el número 6 está en la casilla (6,0) es el átomo ͞
# Que el número 6 está en la casilla (6,1) es el átomo ͨ
# Que el número 6 está en la casilla (6,2) es el átomo Ͳ
# Que el número 6 está en la casilla (6,3) es el átomo ͼ
# Que el número 6 está en la casilla (6,4) es el átomo Ά
# Que el número 6 está en la casilla (6,5) es el átomo ΐ
# Que el número 6 está en la casilla (6,6) es el átomo Κ
# Que el número 6 está en la casilla (6,7) es el átomo Τ
# Que el número 6 está en la casilla (6,8) es el átomo ή
# Que el número 6 está en la casilla (6,9) es el átomo θ
# Que el número 6 está en la casilla (7,0) es el átomo ͟
# Que el número 6 está en la casilla (7,1) es el átomo ͩ
# Que el número 6 está en la casilla (7,2) es el átomo ͳ
# Que el número 6 está en la casilla (7,3) es el átomo ͽ
# Que el número 6 está en la casilla (7,4) es el átomo ·
# Que el número 6 está en la casilla (7,5) es el átomo Α
# Que el número 6 está en la casilla (7,6) es el átomo Λ
# Que el número 6 está en la casilla (7,7) es el átomo Υ
# Que el número 6 está en la casilla (7,8) es el átomo ί
# Que el número 6 está en la casilla (7,9) es el átomo ι
# Que el número 6 está en la casilla (8,0) es el átomo ͠
# Que el número 6 está en la casilla (8,1) es el átomo ͪ
# Que el número 6 está en la casilla (8,2) es el átomo ʹ
# Que el número 6 está en la casilla (8,3) es el átomo ;
# Que el número 6 está en la casilla (8,4) es el átomo Έ
# Que el número 6 está en la casilla (8,5) es el átomo Β
# Que el número 6 está en la casilla (8,6) es el átomo Μ
# Que el número 6 está en la casilla (8,7) es el átomo Φ
# Que el número 6 está en la casilla (8,8) es el átomo ΰ
# Que el número 6 está en la casilla (8,9) es el átomo κ
# Que el número 6 está en la casilla (9,0) es el átomo ͡
# Que el número 6 está en la casilla (9,1) es el átomo ͫ
# Que el número 6 está en la casilla (9,2) es el átomo ͵
# Que el número 6 está en la casilla (9,3) es el átomo Ϳ
# Que el número 6 está en la casilla (9,4) es el átomo Ή
# Que el número 6 está en la casilla (9,5) es el átomo Γ
# Que el número 6 está en la casilla (9,6) es el átomo Ν
# Que el número 6 está en la casilla (9,7) es el átomo Χ
# Que el número 6 está en la casilla (9,8) es el átomo α
# Que el número 6 está en la casilla (9,9) es el átomo λ

# %% [markdown]
# ### Decodificando el caracter
#
# Ahora podemos incluir un método para visualizar más fácilmente la información que porta cada letra proposicional. Esto es, en nuestro ejemplo en cuestión, nuestro objeto `OenCasilla` representa el cruce de información de que un número se encuentra en un lugar. Entonces, al decodificar una letra proposicional, queremos que nos presente claramente esta información y no un caracter inpronunciable (aunque es precisamente este caracter el que usará la máquina).
#
# Para ello podemos usar el siguiente método `escribir`:

# %%
def escribir(self, literal):
    if '-' in literal:
        atomo = literal[1:]
        neg = ' no'
    else:
        atomo = literal
        neg = ''
    x, y, n  = self.inv(atomo)
    return f"El número {n}{neg} está en la casilla ({x},{y})"
    
from types import MethodType

NenC.escribir = MethodType(escribir, NenC)

# %%
atomo = NenC.P([0,1,2])
print(f"El caracter que codifica es {atomo}")
print("\nSu decodificación es:")
NenC.escribir(atomo)
# Out:
# El caracter que codifica es ǒ
#
# Su decodificación es:
# 'El número 2 está en la casilla (0,1)'

# %% [markdown]
# Este método también toma en cuenta si el literal es positivo o negativo:

# %%
NenC.escribir('-' + atomo)
# Out:
# 'El número 2 no está en la casilla (0,1)'

# %% [markdown]
# # Implementación de restricciones <a class="anchor" id="imp"></a>
#
# ([Volver al inicio](#inicio))
#
# Ahora es necesario crear las reglas que limitarán los valores de verdad para las letras proposicionales. En nuestro problema de ejemplo tenemos tres restricciones:
#
# 1. Un número sólo está en una casilla.
# 2. No hay más de un número en una casilla.
# 3. Debe haber por lo menos un número en una casilla.

# %% [markdown]
# ## Restricción 1
#
# Comencemos por considerar la restricción 1, que dice que un número sólo está en una casilla:
#
# $$\bigwedge_{x\in\{0,1\}}\bigwedge_{y\in\{0,1\}}\bigwedge_{n\in Numeros}\left(OenCasilla_{x,y,n}\to\neg\left(\bigvee_{(u,v)\neq (x,y)} OenCasilla_{u,v,n}\right)\right)$$
#
# Saber cómo implementar toda esta fórmula de un solo tirón, con itorias y otorias anidadas, no es fácil. Desarrollaremos esta implementación siguiendo una serie de pasos, cada uno con mayor generalidad que el anterior.
#
# ### Paso 1
#
# La fórmula para representar que si el 0 está en la casilla $(0,0)$, entonces no puede estar en ninguna otra casilla, es la siguiente:
#
# $$OenCasilla_{0,0,0} \to \neg\left(\bigvee_{(u,v)\neq (0,0)} OenCasilla_{u,v,0}\right)$$
#
# Esta fórmula se implementa en Python de la siguiente manera:

# %%
x = 0
y = 0
inicial2 = True
formula2 = ""

for n in range(4):
    casilla = (x,y)
    otras_casillas = [(i,j) for i in X for j in Y if (i,j) != (x,y)]
    formula1 = ''
    inicial = True
    for casilla in otras_casillas:
        u = casilla[0]
        v = casilla[1]
        if inicial:
            formula1 = OenCasilla.P([u,v,n])
            inicial = False
        else:
            formula1 = "(" + formula1 + "O" + OenCasilla.P([u,v,n]) + ")"

    formula1 = "(" + OenCasilla.P([x,y,n]) + ">-" + formula1 + ")"
    print(formula1)
    if inicial2:
        formula2 = formula1
        inicial2 = False
    else:
        formula2 = "(" + formula2 + "Y" + formula1 + ")"
print(formula2)
# Out:
# (Ā>-((ĂOā)Oă))
# (Ą>-((ĆOą)Oć))
# (Ĉ>-((ĊOĉ)Oċ))
# (Č>-((ĎOč)Oď))
# ((((Ā>-((ĂOā)Oă))Y(Ą>-((ĆOą)Oć)))Y(Ĉ>-((ĊOĉ)Oċ)))Y(Č>-((ĎOč)Oď)))

# %% [markdown]
# Observe que la fórmula resultante es difícil de entender a simple vista, aunque un computador pueda trabajarla fácilmente. Para visualizarla de manera más comprensible y entender el significado del string generado por el código anterior, usaremos la función `visualizar_formula` que se encuentra en la librería `Logica`:

# %%
from Logica import visualizar_formula

#print(visualizar_formula(formula1, OenCasilla))
print(visualizar_formula(formula2, OenCasilla))
# Out:
# ((((El número 0 está en la casilla (0,0) >  no ((El número 0 está en la casilla (0,1) O El número 0 está en la casilla (1,0)) O El número 0 está en la casilla (1,1))) Y (El número 1 está en la casilla (0,0) >  no ((El número 1 está en la casilla (0,1) O El número 1 está en la casilla (1,0)) O El número 1 está en la casilla (1,1)))) Y (El número 2 está en la casilla (0,0) >  no ((El número 2 está en la casilla (0,1) O El número 2 está en la casilla (1,0)) O El número 2 está en la casilla (1,1)))) Y (El número 3 está en la casilla (0,0) >  no ((El número 3 está en la casilla (0,1) O El número 3 está en la casilla (1,0)) O El número 3 está en la casilla (1,1))))

# %% [markdown]
# ### Paso 2
#
# Para el siguiente paso, se debe replicar este procedimiento para los demás números. Es decir, se debe crear una regla que indique que, para cada número $n$, si $n$ ocupa la primera casilla, entonces $n$ no está en ninguna otra casilla. La fórmula de lógica proposicional que expresa esta restricción es la siguiente:
#
# $$\bigwedge_{n\in Numeros}\left(OenCasilla_{0,0,n}\to\neg\left(\bigvee_{(u,v)\neq (0,0)} OenCasilla_{u,v,n}\right)\right)$$

# %% [markdown]
# **Ejercicio 1:** Implemente la fórmula anterior como un string de Python.

# %%
x = 0
y = 0
inicial2 = True
formula2 = ""

for n in range(4):
    casilla = (x,y)
    otras_casillas = [(i,j) for i in X for j in Y if (i,j) != (x,y)]
    formula1 = ''
    inicial = True
    for casilla in otras_casillas:
        u = casilla[0]
        v = casilla[1]
        if inicial:
            formula1 = OenCasilla.P([u,v,n])
            inicial = False
        else:
            formula1 = "(" + formula1 + "O" + OenCasilla.P([u,v,n]) + ")"

    formula1 = "(" + OenCasilla.P([x,y,n]) + ">-" + formula1 + ")"
    print(formula1)
    if inicial2:
        formula2 = formula1
        inicial2 = False
    else:
        formula2 = "(" + formula2 + "Y" + formula1 + ")"
print(formula2)

# %% [markdown]
# ---

# %% [markdown]
# ### Paso 3
#
# Ahora que hemos creado la restricción para la casilla $(0,0)$, el siguiente paso consiste en replicar esta misma para todas las demás casillas. Con esto, tendremos que cada número podrá estar en a lo sumo una casilla. La fórmula lógica que expresa esta restricción es la siguiente:
#
# $$\bigwedge_{x\in\{0,1\}}\bigwedge_{y\in\{0,1\}}\bigwedge_{n\in Numeros}\left(OenCasilla_{x,y,n}\to\neg\left(\bigvee_{(u,v)\neq (x,y)} OenCasilla_{u,v,n}\right)\right)$$

# %% [markdown]
# **Ejercicio 2:** Implemente la fórmula anterior como un string de Python.

# %% [markdown]
# ---

# %% [markdown]
# ## Restricción 2
#
# La segunda restricción es que no puede haber más de un número en cada casilla. Es decir, si el número $n$ se encuentra dentro de la casilla $(x,y)$, otro número $m\neq n$ no puede estar dentro de ella. La fórmula lógica que representa esta restricción es la siguiente:
#
# $$\bigwedge_{x\in\{0,1\}}\bigwedge_{y\in\{0,1\}}\bigwedge_{n\in Numeros}\left(OenCasilla_{x,y,n}\to\neg\left(\bigvee_{m\neq n} OenCasilla_{x,y,m}\right)\right)$$

# %% [markdown]
# **Ejercicio 3:** Implemente la fórmula anterior como un string de Python.

# %% [markdown]
# ---

# %% [markdown]
# ## Restricción 3
#
# La tercera restricción es que debe haber por lo menos un número en cada casilla. La fórmula lógica que representa esta restricción es la siguiente:
#
# $$\bigwedge_{x\in\{0,1\}}\bigwedge_{y\in\{0,1\}}\left(\bigvee_{n\in Numeros}OenCasilla_{x,y,n}\right)$$

# %% [markdown]
# **Ejercicio 4:** Implemente la fórmula anterior como un string de Python.

# %% [markdown]
# ---

# %% [markdown]
# En este taller usted aprendió a:
#
# 1) Empaquetar información mediante letras proposicionales.
#
# 2) Usar un objeto descriptor para cruzar información en Python.
#
# 3) Implementar las notaciones $\displaystyle\bigwedge_{x\in SET}$  y  $\displaystyle\bigvee_{x\in SET}$ dentro de Python.
#
# 4) Implementar restricciones como un string que contiene una fórmula en notación inorder.
